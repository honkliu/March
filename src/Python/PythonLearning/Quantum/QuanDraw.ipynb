# %%
print("hello")

a = [[1,2,3], [4,5,6], [7,8,9]]
print(a)
print(a[1:][1])
# Out:
# hello
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]
# [7, 8, 9]

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.linspace(2, 10, 80)
plt.plot(x, np.sin(x))

plt.show()

# %%
import matplotlib.image as mpimag

from os import listdir
from os.path import isfile, join

provinces = os.listdir('d:\Feifei\image')

#print(provinces)

font = {'family': 'KaiTi',
        'size': 16,
        }

#plt.plot([3,3,3])

fig, axs = plt.subplots(ncols=3, nrows=3)

row = 0
col = -1
for province in provinces[0:9]:
    prov_image = mpimag.imread((os.path.join('D:\Feifei\image', province)))
    
    col = col + 1

    if col == 3:
        col = 0
        row = (row + 1) % 3
    plt.axis('off')

#    fig.add_subplot()
    #plt.title(province, fontproperties="KaiTi")
#    plt.title(province[0:-4], fontdict=font)
    axs[row, col].axis('off')
    axs[row, col].set_title(province[0:-4], fontdict=font)
    axs[row, col].imshow(prov_image)

#    plt.imshow(prov_image)
#plt.show()

#fig.set_figheight(500)
#fig.set_figwidth(500)
fig.show()
#plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-dc6dd8e7cfa5> in <module>
#       4 from os.path import isfile, join
#       5
# ----> 6 provinces = os.listdir('d:\Feifei\image')
#       7
#       8 #print(provinces)
#
# NameError: name 'os' is not defined

# %%
fig, axs = plt.subplots(ncols=3, nrows=3)
gs = axs[1, 2].get_gridspec()
# remove the underlying axes
print(axs[0:,-1])
for ax in axs[1:, -1]:
    ax.remove()
#axbig = fig.add_subplot(gs[1:, -1])
#axbig.annotate('Big Axes \nGridSpec[1:, -1]', (0.1, 0.5),
#               xycoords='axes fraction', va='center')

fig.tight_layout()
